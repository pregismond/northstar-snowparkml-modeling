# %% [markdown]
# # Predicting Food Truck Locations Using Snowpark ML and XGBoost
#
# In this project, we use the Snowpark ML library and XGBoost to build a classification model that can predict the location of the Freezing Point food truck on any given day. After training the model, we assess its performance using relevant metrics to gauge accuracy and effectiveness. Then we register the model to the Snowflake Model Registry, logging it with its metadata and key metrics for easy access and management within Snowflake.

# %% [markdown]
# ----

# %% [markdown]
# ### Preliminaries: Installing Libraries
#
# Install the required libraries

# %%
# !pip install snowflake-ml-python
# !pip install snowflake-snowpark-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: snowflake-ml-python in /home/parallels/.local/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: absl-py<2,>=0.15 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.4.0)
# Requirement already satisfied: anyio<4,>=3.5.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (3.7.1)
# Requirement already satisfied: cachetools<6,>=3.1.1 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (5.3.3)
# Requirement already satisfied: cloudpickle>=2.0.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (2.2.1)
# Requirement already satisfied: fsspec<2024,>=2022.11 in /home/parallels/.local/lib/python3.10/site-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python) (2023.12.2)
# Requirement already satisfied: importlib-resources<7,>=6.1.1 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (6.4.0)
# Requirement already satisfied: numpy<2,>=1.23 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.26.4)
# Requirement already satisfied: packaging<24,>=20.9 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (23.2)
# Requirement already satisfied: pandas<3,>=1.0.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (2.2.2)
# Requirement already satisfied: pyarrow in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (16.0.0)
# Requirement already satisfied: pytimeparse<2,>=1.1.8 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.1.8)
# Requirement already satisfied: pyyaml<7,>=6.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (6.0.1)
# Requirement already satisfied: retrying<2,>=1.3.3 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.3.4)
# Requirement already satisfied: s3fs<2024,>=2022.11 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (2023.12.2)
# Requirement already satisfied: scikit-learn<1.4,>=1.2.1 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.3.2)
# Requirement already satisfied: scipy<2,>=1.9 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.13.0)
# Requirement already satisfied: snowflake-connector-python<4,>=3.5.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (3.10.1)
# Requirement already satisfied: snowflake-snowpark-python<2,>=1.15.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.18.0)
# Requirement already satisfied: sqlparse<1,>=0.4 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (0.5.0)
# Requirement already satisfied: typing-extensions<5,>=4.1.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (4.12.2)
# Requirement already satisfied: xgboost<2,>=1.7.3 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-ml-python) (1.7.6)
# Requirement already satisfied: idna>=2.8 in /usr/lib/python3/dist-packages (from anyio<4,>=3.5.0->snowflake-ml-python) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /home/parallels/.local/lib/python3.10/site-packages (from anyio<4,>=3.5.0->snowflake-ml-python) (1.3.1)
# Requirement already satisfied: exceptiongroup in /home/parallels/.local/lib/python3.10/site-packages (from anyio<4,>=3.5.0->snowflake-ml-python) (1.2.0)
# Requirement already satisfied: requests in /home/parallels/.local/lib/python3.10/site-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python) (2.32.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/parallels/.local/lib/python3.10/site-packages (from fsspec[http]<2024,>=2022.11->snowflake-ml-python) (3.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/parallels/.local/lib/python3.10/site-packages (from pandas<3,>=1.0.0->snowflake-ml-python) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas<3,>=1.0.0->snowflake-ml-python) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/parallels/.local/lib/python3.10/site-packages (from pandas<3,>=1.0.0->snowflake-ml-python) (2024.1)
# Requirement already satisfied: six>=1.7.0 in /usr/lib/python3/dist-packages (from retrying<2,>=1.3.3->snowflake-ml-python) (1.16.0)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /home/parallels/.local/lib/python3.10/site-packages (from s3fs<2024,>=2022.11->snowflake-ml-python) (2.13.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/parallels/.local/lib/python3.10/site-packages (from scikit-learn<1.4,>=1.2.1->snowflake-ml-python) (1.4.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/parallels/.local/lib/python3.10/site-packages (from scikit-learn<1.4,>=1.2.1->snowflake-ml-python) (3.4.0)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (42.0.8)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (24.1.0)
# Requirement already satisfied: pyjwt<3.0.0 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2020.6.20)
# Requirement already satisfied: filelock<4,>=3.5 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (3.6.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (4.2.0)
# Requirement already satisfied: tomlkit in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (0.12.5)
# Requirement already satisfied: setuptools>=40.6.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-snowpark-python<2,>=1.15.0->snowflake-ml-python) (70.0.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from snowflake-snowpark-python<2,>=1.15.0->snowflake-ml-python) (0.37.1)
# Requirement already satisfied: botocore<1.34.107,>=1.34.70 in /home/parallels/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python) (1.34.106)
# Requirement already satisfied: wrapt<2.0.0,>=1.10.10 in /home/parallels/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python) (1.16.0)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /home/parallels/.local/lib/python3.10/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python) (0.11.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/parallels/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/parallels/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/parallels/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/parallels/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/parallels/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/parallels/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (4.0.3)
# Requirement already satisfied: pycparser in /home/parallels/.local/lib/python3.10/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4,>=3.5.0->snowflake-connector-python[pandas]<4,>=3.5.0->snowflake-ml-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->fsspec[http]<2024,>=2022.11->snowflake-ml-python) (1.26.5)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/parallels/.local/lib/python3.10/site-packages (from botocore<1.34.107,>=1.34.70->aiobotocore<3.0.0,>=2.5.4->s3fs<2024,>=2022.11->snowflake-ml-python) (1.0.1)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: snowflake-snowpark-python in /home/parallels/.local/lib/python3.10/site-packages (1.18.0)
# Requirement already satisfied: setuptools>=40.6.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-snowpark-python) (70.0.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from snowflake-snowpark-python) (0.37.1)
# Requirement already satisfied: snowflake-connector-python<4.0.0,>=3.10.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-snowpark-python) (3.10.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-snowpark-python) (4.12.2)
# Requirement already satisfied: pyyaml in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-snowpark-python) (6.0.1)
# Requirement already satisfied: cloudpickle!=2.1.0,!=2.2.0,<=2.2.1,>=1.6.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-snowpark-python) (2.2.1)
# Requirement already satisfied: asn1crypto<2.0.0,>0.24.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (1.5.1)
# Requirement already satisfied: cffi<2.0.0,>=1.9 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (1.16.0)
# Requirement already satisfied: cryptography<43.0.0,>=3.1.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (42.0.8)
# Requirement already satisfied: pyOpenSSL<25.0.0,>=16.2.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (24.1.0)
# Requirement already satisfied: pyjwt<3.0.0 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (2.3.0)
# Requirement already satisfied: pytz in /usr/lib/python3/dist-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (2022.1)
# Requirement already satisfied: requests<3.0.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (2.32.3)
# Requirement already satisfied: packaging in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (2020.6.20)
# Requirement already satisfied: filelock<4,>=3.5 in /usr/lib/python3/dist-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (3.6.0)
# Requirement already satisfied: sortedcontainers>=2.4.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (2.4.0)
# Requirement already satisfied: platformdirs<5.0.0,>=2.6.0 in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (4.2.0)
# Requirement already satisfied: tomlkit in /home/parallels/.local/lib/python3.10/site-packages (from snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (0.12.5)
# Requirement already satisfied: pycparser in /home/parallels/.local/lib/python3.10/site-packages (from cffi<2.0.0,>=1.9->snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (2.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0->snowflake-connector-python<4.0.0,>=3.10.0->snowflake-snowpark-python) (1.26.5)

# %% [markdown]
# ### Importing Libraries
#
# Importing the required libraries

# %%
import csv
from credential import params

# Import the required libraries
from snowflake.snowpark import Session
from snowflake.snowpark.version import VERSION
from snowflake.snowpark.functions import col
from snowflake.ml.modeling import preprocessing
from snowflake.ml.modeling.xgboost import XGBClassifier
from snowflake.ml.registry import Registry

# %% [markdown]
# To create a Snowflake session, a dictionary of credentials containing account name, user name, password, and other details can be provided. To simplify this process and avoid exposing credentials, a separate [credential.py](credential.py) file was created. This file is then imported as a library to directly pull the dictionary of credentials.
#
# *IMPORTANT: In a Production environment, it's crucial to secure passwords using secret managers and/or OAuth.*

# %% [markdown]
# ### Creating the Dataset

# %% [markdown]
# Here’s the neighborhood visiting pattern the truck follows:
#
# In January, the truck goes to neighborhood 1 on the 1st, 8th, 15th, 22nd, and 29th, and neighborhood 2 the other days.
#
# From February through November, it goes to:
#
# - Neighborhood 1 on the 1st
# - Neighborhood 2 on the 2nd
# - Neighborhood 3 on the 3rd
# - Neighborhood 4 on the 4th
# - Neighborhood 5 on the 5th
# - Neighborhood 6 on the 6th
# - Neighborhood 7 on the 7th
#
# Then loops back again after visiting neighborhood 7:
#
# - Neighborhood 1 on the 8th
# - Neighborhood 2 on the 9th, and so on, until the next month starts when it then restarts the pattern.
#
# Every December, it only goes to neighborhood 8.

# %%
month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

# %%
pre = {}

for i,month_length in enumerate(month_days):
    month = i + 1

    for day in range(1,month_length+1):
        
        # In January, it goes to neighborhood 1 on Mondays, and neighborhood 2 the other days.
        if ((month) == 1):
            if (day) % 7 == 1:
                pre[(month,day)] = 1
            else:
                pre[(month,day)] = 2
                
        # From February through November, it goes to neighborhood 1 on the 1st, 2 on the 2nd, 3 on the 3rd,
        # 4 on the 4th, 5 on the 5th, 6 on the 6th, and 7 on the 7th, 1 on the 8th, 2 on the 9th, etc.
        elif ((month) <= 11):
            pre[(month,day)] = ((day-1) % 7) + 1

        # Every December, it only goes to neighborhood 8.
        elif ((month) == 12):
            pre[(month,day)] = 8

# %% [markdown]
# By utilizing this neighborhood visiting pattern, we generate data for an entire year.

# %%
# See what the pre dictionary looks like
pre
# Out:
# {(1, 1): 1,
#  (1, 2): 2,
#  (1, 3): 2,
#  (1, 4): 2,
#  (1, 5): 2,
#  (1, 6): 2,
#  (1, 7): 2,
#  (1, 8): 1,
#  (1, 9): 2,
#  (1, 10): 2,
#  (1, 11): 2,
#  (1, 12): 2,
#  (1, 13): 2,
#  (1, 14): 2,
#  (1, 15): 1,
#  (1, 16): 2,
#  (1, 17): 2,
#  (1, 18): 2,
#  (1, 19): 2,
#  (1, 20): 2,
#  (1, 21): 2,
#  (1, 22): 1,
#  (1, 23): 2,
#  (1, 24): 2,
#  (1, 25): 2,
#  (1, 26): 2,
#  (1, 27): 2,
#  (1, 28): 2,
#  (1, 29): 1,
#  (1, 30): 2,
#  (1, 31): 2,
#  (2, 1): 1,
#  (2, 2): 2,
#  (2, 3): 3,
#  (2, 4): 4,
#  (2, 5): 5,
#  (2, 6): 6,
#  (2, 7): 7,
#  (2, 8): 1,
#  (2, 9): 2,
#  (2, 10): 3,
#  (2, 11): 4,
#  (2, 12): 5,
#  (2, 13): 6,
#  (2, 14): 7,
#  (2, 15): 1,
#  (2, 16): 2,
#  (2, 17): 3,
#  (2, 18): 4,
#  (2, 19): 5,
#  (2, 20): 6,
#  (2, 21): 7,
#  (2, 22): 1,
#  (2, 23): 2,
#  (2, 24): 3,
#  (2, 25): 4,
#  (2, 26): 5,
#  (2, 27): 6,
#  (2, 28): 7,
#  (3, 1): 1,
#  (3, 2): 2,
#  (3, 3): 3,
#  (3, 4): 4,
#  (3, 5): 5,
#  (3, 6): 6,
#  (3, 7): 7,
#  (3, 8): 1,
#  (3, 9): 2,
#  (3, 10): 3,
#  (3, 11): 4,
#  (3, 12): 5,
#  (3, 13): 6,
#  (3, 14): 7,
#  (3, 15): 1,
#  (3, 16): 2,
#  (3, 17): 3,
#  (3, 18): 4,
#  (3, 19): 5,
#  (3, 20): 6,
#  (3, 21): 7,
#  (3, 22): 1,
#  (3, 23): 2,
#  (3, 24): 3,
#  (3, 25): 4,
#  (3, 26): 5,
#  (3, 27): 6,
#  (3, 28): 7,
#  (3, 29): 1,
#  (3, 30): 2,
#  (3, 31): 3,
#  (4, 1): 1,
#  (4, 2): 2,
#  (4, 3): 3,
#  (4, 4): 4,
#  (4, 5): 5,
#  (4, 6): 6,
#  (4, 7): 7,
#  (4, 8): 1,
#  (4, 9): 2,
#  (4, 10): 3,
#  (4, 11): 4,
#  (4, 12): 5,
#  (4, 13): 6,
#  (4, 14): 7,
#  (4, 15): 1,
#  (4, 16): 2,
#  (4, 17): 3,
#  (4, 18): 4,
#  (4, 19): 5,
#  (4, 20): 6,
#  (4, 21): 7,
#  (4, 22): 1,
#  (4, 23): 2,
#  (4, 24): 3,
#  (4, 25): 4,
#  (4, 26): 5,
#  (4, 27): 6,
#  (4, 28): 7,
#  (4, 29): 1,
#  (4, 30): 2,
#  (5, 1): 1,
#  (5, 2): 2,
#  (5, 3): 3,
#  (5, 4): 4,
#  (5, 5): 5,
#  (5, 6): 6,
#  (5, 7): 7,
#  (5, 8): 1,
#  (5, 9): 2,
#  (5, 10): 3,
#  (5, 11): 4,
#  (5, 12): 5,
#  (5, 13): 6,
#  (5, 14): 7,
#  (5, 15): 1,
#  (5, 16): 2,
#  (5, 17): 3,
#  (5, 18): 4,
#  (5, 19): 5,
#  (5, 20): 6,
#  (5, 21): 7,
#  (5, 22): 1,
#  (5, 23): 2,
#  (5, 24): 3,
#  (5, 25): 4,
#  (5, 26): 5,
#  (5, 27): 6,
#  (5, 28): 7,
#  (5, 29): 1,
#  (5, 30): 2,
#  (5, 31): 3,
#  (6, 1): 1,
#  (6, 2): 2,
#  (6, 3): 3,
#  (6, 4): 4,
#  (6, 5): 5,
#  (6, 6): 6,
#  (6, 7): 7,
#  (6, 8): 1,
#  (6, 9): 2,
#  (6, 10): 3,
#  (6, 11): 4,
#  (6, 12): 5,
#  (6, 13): 6,
#  (6, 14): 7,
#  (6, 15): 1,
#  (6, 16): 2,
#  (6, 17): 3,
#  (6, 18): 4,
#  (6, 19): 5,
#  (6, 20): 6,
#  (6, 21): 7,
#  (6, 22): 1,
#  (6, 23): 2,
#  (6, 24): 3,
#  (6, 25): 4,
#  (6, 26): 5,
#  (6, 27): 6,
#  (6, 28): 7,
#  (6, 29): 1,
#  (6, 30): 2,
#  (7, 1): 1,
#  (7, 2): 2,
#  (7, 3): 3,
#  (7, 4): 4,
#  (7, 5): 5,
#  (7, 6): 6,
#  (7, 7): 7,
#  (7, 8): 1,
#  (7, 9): 2,
#  (7, 10): 3,
#  (7, 11): 4,
#  (7, 12): 5,
#  (7, 13): 6,
#  (7, 14): 7,
#  (7, 15): 1,
#  (7, 16): 2,
#  (7, 17): 3,
#  (7, 18): 4,
#  (7, 19): 5,
#  (7, 20): 6,
#  (7, 21): 7,
#  (7, 22): 1,
#  (7, 23): 2,
#  (7, 24): 3,
#  (7, 25): 4,
#  (7, 26): 5,
#  (7, 27): 6,
#  (7, 28): 7,
#  (7, 29): 1,
#  (7, 30): 2,
#  (7, 31): 3,
#  (8, 1): 1,
#  (8, 2): 2,
#  (8, 3): 3,
#  (8, 4): 4,
#  (8, 5): 5,
#  (8, 6): 6,
#  (8, 7): 7,
#  (8, 8): 1,
#  (8, 9): 2,
#  (8, 10): 3,
#  (8, 11): 4,
#  (8, 12): 5,
#  (8, 13): 6,
#  (8, 14): 7,
#  (8, 15): 1,
#  (8, 16): 2,
#  (8, 17): 3,
#  (8, 18): 4,
#  (8, 19): 5,
#  (8, 20): 6,
#  (8, 21): 7,
#  (8, 22): 1,
#  (8, 23): 2,
#  (8, 24): 3,
#  (8, 25): 4,
#  (8, 26): 5,
#  (8, 27): 6,
#  (8, 28): 7,
#  (8, 29): 1,
#  (8, 30): 2,
#  (8, 31): 3,
#  (9, 1): 1,
#  (9, 2): 2,
#  (9, 3): 3,
#  (9, 4): 4,
#  (9, 5): 5,
#  (9, 6): 6,
#  (9, 7): 7,
#  (9, 8): 1,
#  (9, 9): 2,
#  (9, 10): 3,
#  (9, 11): 4,
#  (9, 12): 5,
#  (9, 13): 6,
#  (9, 14): 7,
#  (9, 15): 1,
#  (9, 16): 2,
#  (9, 17): 3,
#  (9, 18): 4,
#  (9, 19): 5,
#  (9, 20): 6,
#  (9, 21): 7,
#  (9, 22): 1,
#  (9, 23): 2,
#  (9, 24): 3,
#  (9, 25): 4,
#  (9, 26): 5,
#  (9, 27): 6,
#  (9, 28): 7,
#  (9, 29): 1,
#  (9, 30): 2,
#  (10, 1): 1,
#  (10, 2): 2,
#  (10, 3): 3,
#  (10, 4): 4,
#  (10, 5): 5,
#  (10, 6): 6,
#  (10, 7): 7,
#  (10, 8): 1,
#  (10, 9): 2,
#  (10, 10): 3,
#  (10, 11): 4,
#  (10, 12): 5,
#  (10, 13): 6,
#  (10, 14): 7,
#  (10, 15): 1,
#  (10, 16): 2,
#  (10, 17): 3,
#  (10, 18): 4,
#  (10, 19): 5,
#  (10, 20): 6,
#  (10, 21): 7,
#  (10, 22): 1,
#  (10, 23): 2,
#  (10, 24): 3,
#  (10, 25): 4,
#  (10, 26): 5,
#  (10, 27): 6,
#  (10, 28): 7,
#  (10, 29): 1,
#  (10, 30): 2,
#  (10, 31): 3,
#  (11, 1): 1,
#  (11, 2): 2,
#  (11, 3): 3,
#  (11, 4): 4,
#  (11, 5): 5,
#  (11, 6): 6,
#  (11, 7): 7,
#  (11, 8): 1,
#  (11, 9): 2,
#  (11, 10): 3,
#  (11, 11): 4,
#  (11, 12): 5,
#  (11, 13): 6,
#  (11, 14): 7,
#  (11, 15): 1,
#  (11, 16): 2,
#  (11, 17): 3,
#  (11, 18): 4,
#  (11, 19): 5,
#  (11, 20): 6,
#  (11, 21): 7,
#  (11, 22): 1,
#  (11, 23): 2,
#  (11, 24): 3,
#  (11, 25): 4,
#  (11, 26): 5,
#  (11, 27): 6,
#  (11, 28): 7,
#  (11, 29): 1,
#  (11, 30): 2,
#  (12, 1): 8,
#  (12, 2): 8,
#  (12, 3): 8,
#  (12, 4): 8,
#  (12, 5): 8,
#  (12, 6): 8,
#  (12, 7): 8,
#  (12, 8): 8,
#  (12, 9): 8,
#  (12, 10): 8,
#  (12, 11): 8,
#  (12, 12): 8,
#  (12, 13): 8,
#  (12, 14): 8,
#  (12, 15): 8,
#  (12, 16): 8,
#  (12, 17): 8,
#  (12, 18): 8,
#  (12, 19): 8,
#  (12, 20): 8,
#  (12, 21): 8,
#  (12, 22): 8,
#  (12, 23): 8,
#  (12, 24): 8,
#  (12, 25): 8,
#  (12, 26): 8,
#  (12, 27): 8,
#  (12, 28): 8,
#  (12, 29): 8,
#  (12, 30): 8,
#  (12, 31): 8}

# %% [markdown]
# ### Concatenate DataFrame 20 Times and Upload to Snowflake

# %% [markdown]
# *Note: The following steps were not covered in the course. This is just one method to concatenate the DataFrame 20 times and upload it to Snowflake. Other approaches could involve using Pandas or the Snowsight UI, but I chose to complete it using only Snowpark and Python.*
#
# Convert the dictionary to a CSV file

# %%
with open("pre.csv", "w", newline="") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["month", "day", "neighborhood"])
    for (month, day), neighborhood in pre.items():
        writer.writerow([month, day, neighborhood])

# %% [markdown]
# Create a Session with the necessary connection info

# %%
session = Session.builder.configs(params).create()

# %%
snowflake_env = session.sql("SELECT current_user(), current_version()").collect()
snowpark_version = VERSION

# %% [markdown]
# Create a virtual warehouse, database, and schema

# %%
session.sql("CREATE OR REPLACE WAREHOUSE FREEZING_POINT_WH WITH WAREHOUSE_SIZE='X-SMALL'").collect()
session.sql("USE WAREHOUSE FREEZING_POINT_WH").collect()
session.sql("CREATE OR REPLACE DATABASE FREEZING_POINT_DB").collect()
session.sql("CREATE OR REPLACE SCHEMA FREEZING_POINT_DB.FREEZING_POINT_SCHEMA").collect()
# Out:
# [Row(status='Schema FREEZING_POINT_SCHEMA successfully created.')]

# %%
print("Current Environment Details:")
print("---------------------------------")
print(f"User                        : {snowflake_env[0][0]}")
print(f"Role                        : {session.get_current_role()}")
print(f"Database                    : {session.get_current_database()}")
print(f"Schema                      : {session.get_current_schema()}")
print(f"Warehouse                   : {session.get_current_warehouse()}")
print(f"Snowflake version           : {snowflake_env[0][1]}")
print(f"Snowpark for Python version : {snowpark_version[0]}.{snowpark_version[1]}.{snowpark_version[2]}")
print("---------------------------------")
# Out:
# Current Environment Details:
# ---------------------------------
# User                        : PREGISMOND
# Role                        : "ACCOUNTADMIN"
# Database                    : "FREEZING_POINT_DB"
# Schema                      : "FREEZING_POINT_SCHEMA"
# Warehouse                   : "FREEZING_POINT_WH"
# Snowflake version           : 8.33.1
# Snowpark for Python version : 1.18.0
# ---------------------------------

# %% [markdown]
# Next, we create a stage and put the CSV file into it.

# %%
session.sql("CREATE OR REPLACE STAGE FREEZING_POINT_STAGE").collect()
session.file.put(local_file_name="./pre.csv",
                 stage_location="@FREEZING_POINT_STAGE", 
                 auto_compress=False,
                 overwrite = True)
# Out:
# [PutResult(source='pre.csv', target='pre.csv', source_size=2928, target_size=2944, source_compression='NONE', target_compression='NONE', status='UPLOADED', message='')]

# %% [markdown]
# <img src="images/11_snowpark.png">

# %% [markdown]
# Create a table with defined schema

# %%
session.sql("""
CREATE OR REPLACE TABLE DF_PRE (
    Month NUMBER,
    Day NUMBER,
    Neighborhood NUMBER
);
""").collect()
# Out:
# [Row(status='Table DF_PRE successfully created.')]

# %% [markdown]
# Copy data from stage to table.

# %%
session.sql("""
COPY INTO DF_PRE
FROM @FREEZING_POINT_STAGE/pre.csv
FILE_FORMAT = (TYPE = 'CSV', FIELD_OPTIONALLY_ENCLOSED_BY = '"' SKIP_HEADER = 1);
""").collect()
# Out:
# [Row(file='freezing_point_stage/pre.csv', status='LOADED', rows_parsed=365, rows_loaded=365, error_limit=1, errors_seen=0, first_error=None, first_error_line=None, first_error_character=None, first_error_column_name=None)]

# %% [markdown]
# <img src="images/13_snowpark.png">

# %% [markdown]
# Create a DataFrame that points to `DF_PRE` table

# %%
df_pre = session.table("FREEZING_POINT_DB.FREEZING_POINT_SCHEMA.DF_PRE")

# %% [markdown]
# Concatenate the DataFrame with itself 20 times
#
# * Using `union_all` to combine the DataFrames without removing duplicates

# %%
df_clean = df_pre
for _ in range(19):
    df_clean = df_clean.union_all(df_pre)

# %% [markdown]
# Save the combined DataFrame to Snowflake

# %%
df_clean.write.mode("overwrite").save_as_table("DF_CLEAN")

# %% [markdown]
# <img src="images/16_snowpark.png">

# %% [markdown]
# ### Loading the data, processing the data, training the model, and evaluating

# %% [markdown]
# Create a DataFrame that points to `DF_CLEAN` table

# %%
snowpark_df = session.table("FREEZING_POINT_DB.FREEZING_POINT_SCHEMA.DF_CLEAN")

# %% [markdown]
# Show the first forty rows of the DataFrame

# %%
snowpark_df.show(n=40)
# Out:
# ------------------------------------
# |"MONTH"  |"DAY"  |"NEIGHBORHOOD"  |
# ------------------------------------
# |1        |1      |1               |
# |1        |2      |2               |
# |1        |3      |2               |
# |1        |4      |2               |
# |1        |5      |2               |
# |1        |6      |2               |
# |1        |7      |2               |
# |1        |8      |1               |
# |1        |9      |2               |
# |1        |10     |2               |
# |1        |11     |2               |
# |1        |12     |2               |
# |1        |13     |2               |
# |1        |14     |2               |
# |1        |15     |1               |
# |1        |16     |2               |
# |1        |17     |2               |
# |1        |18     |2               |
# |1        |19     |2               |
# |1        |20     |2               |
# |1        |21     |2               |
# |1        |22     |1               |
# |1        |23     |2               |
# |1        |24     |2               |
# |1        |25     |2               |
# |1        |26     |2               |
# |1        |27     |2               |
# |1        |28     |2               |
# |1        |29     |1               |
# |1        |30     |2               |
# |1        |31     |2               |
# |2        |1      |1               |
# |2        |2      |2               |
# |2        |3      |3               |
# |2        |4      |4               |
# |2        |5      |5               |
# |2        |6      |6               |
# |2        |7      |7               |
# |2        |8      |1               |
# |2        |9      |2               |
# ------------------------------------

# %% [markdown]
# Count the rows in the DataFrame
#
# * Check that we have 7,300 rows, which is 365 * 20

# %%
snowpark_df.count()
# Out:
# 7300

# %% [markdown]
# We can generate descriptive statistics to view some basic statistical details like count, mean, standard deviation, etc.
#
# Examine that the range of values are what we'd expect:
#
# * 1 - 12 for months
# * 1 - 31 for days
# * 1 - 8 for neighborhoods

# %%
snowpark_df.describe().show()
# Out:
# ---------------------------------------------------------------------------
# |"SUMMARY"  |"MONTH"             |"DAY"              |"NEIGHBORHOOD"      |
# ---------------------------------------------------------------------------
# |count      |7300.0              |7300.0             |7300.0              |
# |mean       |6.526027            |15.720548          |4.019178            |
# |stddev     |3.4480874408866145  |8.796849549696756  |2.2738080393911884  |
# |min        |1.0                 |1.0                |1.0                 |
# |max        |12.0                |31.0               |8.0                 |
# ---------------------------------------------------------------------------

# %% [markdown]
# Group by Neighborhood, and show the counts

# %%
snowpark_df.group_by("Neighborhood").count().show()
# Out:
# ----------------------------
# |"NEIGHBORHOOD"  |"COUNT"  |
# ----------------------------
# |1               |1080     |
# |2               |1500     |
# |3               |900      |
# |4               |800      |
# |5               |800      |
# |6               |800      |
# |7               |800      |
# |8               |620      |
# ----------------------------

# %% [markdown]
# As we can see above, neighborhood 2 is the most popular as it gets visited the most each January. Neighborhood 8 gets visited each December, but is never visited any other time during the year, so it has the lowest count.

# %% [markdown]
# With our data prepared, we can now use Snowpark ML to predict which neighborhood the food truck will visit on any given day in the future.
#
# The `XGBClassifier` requires labels to be in the range of 0-7, rather than 1-8, which is how our neighborhoods are currently numbered. To scale the target "Neighborhood", we can use `LabelEncoder`, which takes an input column and produces an output column, automatically subtracting one from each value.
#
# Next, we apply the `fit` method on this LabelEncoder. Finally, we use the `transform` method on the fitted Snowpark DataFrame.

# %%
# Use scikit-learn's LabelEncoder -- a more general solution -- through Snowpark ML
le = preprocessing.LabelEncoder(input_cols=['NEIGHBORHOOD'], output_cols= ['NEIGHBORHOOD2'], drop_input_cols=True)

# Apply the LabelEncoder
fitted = le.fit(snowpark_df.select("NEIGHBORHOOD"))

snowpark_df_prepared = fitted.transform(snowpark_df)

# %% [markdown]
# Show the DataFrame

# %%
snowpark_df_prepared.show()
# Out:
# -------------------------------------
# |"NEIGHBORHOOD2"  |"MONTH"  |"DAY"  |
# -------------------------------------
# |0.0              |1        |1      |
# |1.0              |1        |2      |
# |1.0              |1        |3      |
# |1.0              |1        |4      |
# |1.0              |1        |5      |
# |1.0              |1        |6      |
# |1.0              |1        |7      |
# |0.0              |1        |8      |
# |1.0              |1        |9      |
# |1.0              |1        |10     |
# -------------------------------------

# %% [markdown]
# Split the data into a training set and a test set
#
# Here we're using `randomSplit` from Snowpark ML, even though the underlying functionality is derived from scikit-learn. We'll set aside 10% of our 20 years of truck location data for testing.

# %%
train_snowpark_df, test_snowpark_df = snowpark_df_prepared.randomSplit([0.9, 0.1])

# %% [markdown]
# Save training data as `DF_CLEAN_TRAIN` and test data as `DF_CLEAN_TEST` to our Snowflake instance.

# %%
# Save training data
train_snowpark_df.write.mode("overwrite").save_as_table("DF_CLEAN_TRAIN")

# Save test data
test_snowpark_df.write.mode("overwrite").save_as_table("DF_CLEAN_TEST")

# %% [markdown]
# <img src="images/25_snowpark.png">
#
# <img src="images/25.1_snowpark.png">

# %% [markdown]
# Create and train the `XGBClassifier` model
#
# Here we provide our days and months data along with the neighborhood target variable to the `XGBClassifier`. The classifier will use this information to predict the neighborhood where the truck is located.
#
# The feature columns are the columns the `XGBClassifier` will use to learn and predict the label column.
#
# Next, we call the `fit` method on the model, passing our DataFrame as the argument. This `fit` method initiates the training process.

# %%
FEATURE_COLS = ["MONTH", "DAY"]
LABEL_COLS = ["NEIGHBORHOOD2"]

# Train an XGBoost model on snowflake.
xgboost_model = XGBClassifier(
    input_cols=FEATURE_COLS,
    label_cols=LABEL_COLS
)

xgboost_model.fit(train_snowpark_df)

# %% [markdown]
# Check the accuracy using scikit-learn's `score` functionality through Snowpark ML
#
# The truck driver schedule was deliberately made very regular to test how well XGBoost can detect strange yet consistent patterns in the data.

# %%
accuracy = xgboost_model.score(test_snowpark_df)

print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 100.00%

# %% [markdown]
# The XGBoost classifier we trained, when applied to the test set, made 730 predictions and got 730 of those correct.

# %% [markdown]
# ### Register Model to Snowflake Model Registry

# %% [markdown]
# *Note: The following step was not included in the course. We can load our model into the Snowflake Model Registry to ensure easy access later and to keep track of all our models.*
#
# Load `xgboost_model` into the Snowflake Model Registry with key metrics.

# %%
# Register the model to the Snowflake model registry
registry = Registry(session)

# Define key metrics
key_metrics = {"accuracy": accuracy}

# Log model to registry
model_ref = registry.log_model(
    xgboost_model,
    model_name="FREEZING_POINT_MODEL",
    version_name="v1",
    metrics=key_metrics,
    options={"relax_version": True}
)

# %% [markdown]
# <img src="images/28.0_snowpark.png">
#
# <img src="images/28.1_snowpark.png">

# %% [markdown]
# ### Stop Snowpark Session

# %%
session.close()

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-08-19|0.2|Pravin Regismond|Modified to include:<br>- calling credential.py containing a dictionary of credentials<br>- concatenate DataFrame 20 times and upload to Snowflake<br>- register model to Snowflake Model Registry|
# |2023-04-27|0.1|Peter Olson|Initial Version|
